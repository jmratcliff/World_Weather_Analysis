# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set of random latitude and longitude combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# list for holding cities
cities = []
# Identify the nearest city for each latitude and longitude combos
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If city is unique add it to list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %%
# Import requests library
import requests

# Import the API key
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list ot hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests. get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the dae to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description": city_weather_description,
                         "Date": city_date})
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------")
print("Data Retrieval Complete      ")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | shelburne
# Processing Record 2 of Set 1 | coihaique
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | hofn
# Processing Record 6 of Set 1 | dingle
# Processing Record 7 of Set 1 | san mateo del mar
# Processing Record 8 of Set 1 | nelson bay
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | kartaly
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | bossangoa
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | marsa matruh
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | lincoln
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | grand gaube
# Processing Record 32 of Set 1 | shache
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | northam
# Processing Record 36 of Set 1 | lebanon
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | zyryanovsk
# Processing Record 39 of Set 1 | capinzal
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | poum
# Processing Record 42 of Set 1 | shcholkine
# City not found. Skipping...
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | marsh harbour
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | amod
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | kainantu
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | krasnoslobodsk
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | nantucket
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | isangel
# Processing Record 9 of Set 2 | wad madani
# Processing Record 10 of Set 2 | mayo
# Processing Record 11 of Set 2 | hernani
# Processing Record 12 of Set 2 | upata
# Processing Record 13 of Set 2 | ngama
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | mehamn
# Processing Record 16 of Set 2 | carballo
# Processing Record 17 of Set 2 | wuda
# Processing Record 18 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | am timan
# Processing Record 22 of Set 2 | nizhniy ingash
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | goulburn
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | kendari
# Processing Record 32 of Set 2 | tubuala
# Processing Record 33 of Set 2 | necochea
# Processing Record 34 of Set 2 | acarau
# Processing Record 35 of Set 2 | nha trang
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | dangriga
# Processing Record 38 of Set 2 | bandarbeyla
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | chimoio
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | saint-joseph
# Processing Record 43 of Set 2 | newport
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | vardo
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | ayr
# Processing Record 50 of Set 2 | usak
# Processing Record 1 of Set 3 | high prairie
# Processing Record 2 of Set 3 | masumbwe
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 3 | arman
# Processing Record 6 of Set 3 | port-gentil
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | biankouma
# Processing Record 9 of Set 3 | pandamatenga
# Processing Record 10 of Set 3 | broken hill
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | dali
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | launceston
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | mitsamiouli
# Processing Record 20 of Set 3 | muros
# Processing Record 21 of Set 3 | gremyachye
# City not found. Skipping...
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | torbay
# Processing Record 24 of Set 3 | dosso
# Processing Record 25 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 28 of Set 3 | lata
# Processing Record 29 of Set 3 | mwinilunga
# Processing Record 30 of Set 3 | limbang
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | vanimo
# Processing Record 33 of Set 3 | viransehir
# Processing Record 34 of Set 3 | brae
# Processing Record 35 of Set 3 | atherton
# Processing Record 36 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 37 of Set 3 | qasigiannguit
# Processing Record 38 of Set 3 | smithers
# Processing Record 39 of Set 3 | trincomalee
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | nizhnevartovsk
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | tigzirt
# Processing Record 44 of Set 3 | solnechnyy
# Processing Record 45 of Set 3 | quelimane
# Processing Record 46 of Set 3 | bandar-e lengeh
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | san andres
# Processing Record 49 of Set 3 | praia da vitoria
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | saint-augustin
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | great yarmouth
# Processing Record 7 of Set 4 | namatanai
# Processing Record 8 of Set 4 | venice
# Processing Record 9 of Set 4 | paamiut
# Processing Record 10 of Set 4 | novyy urengoy
# Processing Record 11 of Set 4 | balikpapan
# Processing Record 12 of Set 4 | benjamin constant
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | kuruman
# Processing Record 16 of Set 4 | pisco
# Processing Record 17 of Set 4 | sri aman
# Processing Record 18 of Set 4 | viedma
# Processing Record 19 of Set 4 | nyrob
# Processing Record 20 of Set 4 | barcelos
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | lensk
# Processing Record 23 of Set 4 | mareeba
# Processing Record 24 of Set 4 | palembang
# Processing Record 25 of Set 4 | ewa beach
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | bilma
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | altay
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | yerbogachen
# Processing Record 33 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | sheboygan
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | kuah
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | lahij
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | san vicente
# Processing Record 44 of Set 4 | uige
# Processing Record 45 of Set 4 | sainte-suzanne
# Processing Record 46 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 4 | banjar
# Processing Record 48 of Set 4 | dolores
# Processing Record 49 of Set 4 | rio brilhante
# Processing Record 50 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 1 of Set 5 | namuac
# Processing Record 2 of Set 5 | georgiyevka
# Processing Record 3 of Set 5 | pouembout
# Processing Record 4 of Set 5 | shakhrinau
# City not found. Skipping...
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | innisfail
# Processing Record 7 of Set 5 | kayes
# Processing Record 8 of Set 5 | illapel
# Processing Record 9 of Set 5 | pahrump
# Processing Record 10 of Set 5 | port said
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | itaituba
# Processing Record 13 of Set 5 | newcastleton
# Processing Record 14 of Set 5 | gambo
# Processing Record 15 of Set 5 | zabol
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | alice springs
# Processing Record 18 of Set 5 | zhicheng
# Processing Record 19 of Set 5 | udachnyy
# Processing Record 20 of Set 5 | bemidji
# Processing Record 21 of Set 5 | matiari
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | beira
# Processing Record 24 of Set 5 | mar del plata
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | solntsevo
# Processing Record 27 of Set 5 | ketchikan
# Processing Record 28 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 29 of Set 5 | mahebourg
# Processing Record 30 of Set 5 | dikson
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | port blair
# Processing Record 33 of Set 5 | henties bay
# Processing Record 34 of Set 5 | pamplona
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | sola
# Processing Record 37 of Set 5 | westport
# Processing Record 38 of Set 5 | nakhon si thammarat
# Processing Record 39 of Set 5 | shieli
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | leticia
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | ballitoville
# Processing Record 46 of Set 5 | waipawa
# Processing Record 47 of Set 5 | zaraza
# Processing Record 48 of Set 5 | kingsland
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | aksarka
# Processing Record 1 of Set 6 | berdigestyakh
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | cayenne
# Processing Record 4 of Set 6 | bombay
# Processing Record 5 of Set 6 | awbari
# Processing Record 6 of Set 6 | new norfolk
# Processing Record 7 of Set 6 | boende
# Processing Record 8 of Set 6 | stornoway
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | qaqortoq
# Processing Record 12 of Set 6 | calama
# Processing Record 13 of Set 6 | concepcion del oro
# Processing Record 14 of Set 6 | la libertad
# Processing Record 15 of Set 6 | martapura
# Processing Record 16 of Set 6 | russell
# Processing Record 17 of Set 6 | biryusinsk
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | santa fe
# Processing Record 22 of Set 6 | yumbo
# Processing Record 23 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | kosh-agach
# Processing Record 26 of Set 6 | iwanai
# Processing Record 27 of Set 6 | vostok
# Processing Record 28 of Set 6 | jamsa
# Processing Record 29 of Set 6 | kodiak
# Processing Record 30 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 6 | iqaluit
# Processing Record 32 of Set 6 | korla
# Processing Record 33 of Set 6 | leh
# Processing Record 34 of Set 6 | san carlos de bariloche
# Processing Record 35 of Set 6 | oksfjord
# Processing Record 36 of Set 6 | san jose
# Processing Record 37 of Set 6 | mae chan
# Processing Record 38 of Set 6 | hobyo
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | santa marta
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 6 | kasungu
# Processing Record 44 of Set 6 | gimli
# Processing Record 45 of Set 6 | dabakala
# Processing Record 46 of Set 6 | malanje
# Processing Record 47 of Set 6 | gberia fotombu
# Processing Record 48 of Set 6 | husavik
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | khvatovka
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | toora-khem
# Processing Record 5 of Set 7 | sirhind
# Processing Record 6 of Set 7 | shirpur
# Processing Record 7 of Set 7 | lewisporte
# Processing Record 8 of Set 7 | ocean city
# Processing Record 9 of Set 7 | yinchuan
# Processing Record 10 of Set 7 | araceli
# Processing Record 11 of Set 7 | maneadero
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | hualmay
# Processing Record 14 of Set 7 | hof
# Processing Record 15 of Set 7 | svalyava
# Processing Record 16 of Set 7 | ous
# Processing Record 17 of Set 7 | progreso
# Processing Record 18 of Set 7 | gerash
# Processing Record 19 of Set 7 | vilhena
# Processing Record 20 of Set 7 | razdolinsk
# Processing Record 21 of Set 7 | san lorenzo
# Processing Record 22 of Set 7 | bayangol
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | magadan
# Processing Record 26 of Set 7 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 27 of Set 7 | naze
# Processing Record 28 of Set 7 | hambantota
# Processing Record 29 of Set 7 | shenzhen
# Processing Record 30 of Set 7 | sterling
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | kaeo
# Processing Record 33 of Set 7 | kerema
# Processing Record 34 of Set 7 | tuy hoa
# Processing Record 35 of Set 7 | itoman
# Processing Record 36 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 7 | galbshtadt
# Processing Record 38 of Set 7 | cabo san lucas
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | werda
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | pemangkat
# Processing Record 44 of Set 7 | bogovarovo
# Processing Record 45 of Set 7 | kostolac
# Processing Record 46 of Set 7 | abu samrah
# Processing Record 47 of Set 7 | cooma
# Processing Record 48 of Set 7 | pevek
# Processing Record 49 of Set 7 | lethem
# Processing Record 50 of Set 7 | carbondale
# Processing Record 1 of Set 8 | lahaina
# Processing Record 2 of Set 8 | estreito
# Processing Record 3 of Set 8 | longyearbyen
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | kazachinskoye
# Processing Record 6 of Set 8 | porbandar
# Processing Record 7 of Set 8 | kankon
# Processing Record 8 of Set 8 | milkovo
# Processing Record 9 of Set 8 | broome
# Processing Record 10 of Set 8 | lucea
# Processing Record 11 of Set 8 | north bend
# Processing Record 12 of Set 8 | sioux lookout
# Processing Record 13 of Set 8 | krasnogorsk
# Processing Record 14 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 8 | catamarca
# Processing Record 16 of Set 8 | te anau
# Processing Record 17 of Set 8 | luanda
# Processing Record 18 of Set 8 | kupang
# Processing Record 19 of Set 8 | quang ngai
# Processing Record 20 of Set 8 | san pedro
# Processing Record 21 of Set 8 | koundara
# Processing Record 22 of Set 8 | kirakira
# Processing Record 23 of Set 8 | nyurba
# Processing Record 24 of Set 8 | elat
# Processing Record 25 of Set 8 | mabai
# Processing Record 26 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 8 | sechura
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | wembley
# Processing Record 30 of Set 8 | onguday
# Processing Record 31 of Set 8 | ayorou
# Processing Record 32 of Set 8 | ndele
# Processing Record 33 of Set 8 | sinnamary
# Processing Record 34 of Set 8 | nemuro
# Processing Record 35 of Set 8 | turukhansk
# Processing Record 36 of Set 8 | cartagena
# Processing Record 37 of Set 8 | pochutla
# Processing Record 38 of Set 8 | la roche-en-ardenne
# Processing Record 39 of Set 8 | batagay-alyta
# Processing Record 40 of Set 8 | la macarena
# Processing Record 41 of Set 8 | belyy yar
# Processing Record 42 of Set 8 | ghanzi
# Processing Record 43 of Set 8 | mecca
# Processing Record 44 of Set 8 | hay river
# Processing Record 45 of Set 8 | conceicao do araguaia
# Processing Record 46 of Set 8 | plettenberg bay
# Processing Record 47 of Set 8 | xuddur
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | grindavik
# Processing Record 50 of Set 8 | tilichiki
# Processing Record 1 of Set 9 | kasongo-lunda
# Processing Record 2 of Set 9 | bubaque
# Processing Record 3 of Set 9 | vila
# Processing Record 4 of Set 9 | peleduy
# Processing Record 5 of Set 9 | kawalu
# Processing Record 6 of Set 9 | tanhacu
# Processing Record 7 of Set 9 | arbuzynka
# Processing Record 8 of Set 9 | joshimath
# Processing Record 9 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 9 | jaru
# Processing Record 11 of Set 9 | flinders
# Processing Record 12 of Set 9 | kizukuri
# Processing Record 13 of Set 9 | mtambile
# Processing Record 14 of Set 9 | cidreira
# Processing Record 15 of Set 9 | pacifica
# Processing Record 16 of Set 9 | trinidad
# Processing Record 17 of Set 9 | coahuayana
# Processing Record 18 of Set 9 | schattdorf
# Processing Record 19 of Set 9 | blythe
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | talara
# Processing Record 22 of Set 9 | kieta
# Processing Record 23 of Set 9 | samarai
# Processing Record 24 of Set 9 | kumylzhenskaya
# Processing Record 25 of Set 9 | vysokogornyy
# Processing Record 26 of Set 9 | bhor
# Processing Record 27 of Set 9 | havre-saint-pierre
# Processing Record 28 of Set 9 | abha
# Processing Record 29 of Set 9 | carutapera
# Processing Record 30 of Set 9 | buritizeiro
# Processing Record 31 of Set 9 | leningradskiy
# Processing Record 32 of Set 9 | cabo rojo
# Processing Record 33 of Set 9 | bathsheba
# Processing Record 34 of Set 9 | doka
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | roswell
# Processing Record 37 of Set 9 | glendive
# Processing Record 38 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 9 | rosarito
# Processing Record 40 of Set 9 | savalou
# Processing Record 41 of Set 9 | urumqi
# Processing Record 42 of Set 9 | dungarvan
# Processing Record 43 of Set 9 | jackson
# Processing Record 44 of Set 9 | solton
# Processing Record 45 of Set 9 | havelock
# Processing Record 46 of Set 9 | oussouye
# Processing Record 47 of Set 9 | daman
# Processing Record 48 of Set 9 | yumen
# Processing Record 49 of Set 9 | kyabe
# Processing Record 50 of Set 9 | belaya gora
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 10 | beringovskiy
# Processing Record 3 of Set 10 | chuy
# Processing Record 4 of Set 10 | bethel
# Processing Record 5 of Set 10 | natchitoches
# Processing Record 6 of Set 10 | mayumba
# Processing Record 7 of Set 10 | yarada
# Processing Record 8 of Set 10 | hindupur
# Processing Record 9 of Set 10 | marang
# Processing Record 10 of Set 10 | mudhol
# Processing Record 11 of Set 10 | athabasca
# Processing Record 12 of Set 10 | kloulklubed
# Processing Record 13 of Set 10 | sudak
# Processing Record 14 of Set 10 | asau
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | beinamar
# Processing Record 17 of Set 10 | saint george
# Processing Record 18 of Set 10 | roma
# Processing Record 19 of Set 10 | anqing
# Processing Record 20 of Set 10 | richards bay
# Processing Record 21 of Set 10 | jalu
# Processing Record 22 of Set 10 | klamath falls
# Processing Record 23 of Set 10 | rochester
# Processing Record 24 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 10 | wewak
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | banamba
# Processing Record 28 of Set 10 | clearwater
# Processing Record 29 of Set 10 | mananjary
# Processing Record 30 of Set 10 | andselv
# City not found. Skipping...
# Processing Record 31 of Set 10 | soroti
# Processing Record 32 of Set 10 | saint-georges
# Processing Record 33 of Set 10 | sistranda
# Processing Record 34 of Set 10 | matai
# Processing Record 35 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 10 | finnsnes
# Processing Record 37 of Set 10 | bani walid
# Processing Record 38 of Set 10 | oneonta
# Processing Record 39 of Set 10 | hanna
# Processing Record 40 of Set 10 | berlevag
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | ust-kuyga
# Processing Record 43 of Set 10 | rafaela
# Processing Record 44 of Set 10 | zhanaozen
# Processing Record 45 of Set 10 | sakaiminato
# Processing Record 46 of Set 10 | olafsvik
# Processing Record 47 of Set 10 | sao joao da barra
# Processing Record 48 of Set 10 | genhe
# Processing Record 49 of Set 10 | mount isa
# Processing Record 50 of Set 10 | markala
# Processing Record 1 of Set 11 | oudtshoorn
# Processing Record 2 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 11 | ponta do sol
# Processing Record 4 of Set 11 | dongsheng
# Processing Record 5 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 11 | oranjestad
# Processing Record 7 of Set 11 | xining
# Processing Record 8 of Set 11 | acari
# Processing Record 9 of Set 11 | tulancingo
# Processing Record 10 of Set 11 | acajutla
# Processing Record 11 of Set 11 | basco
# Processing Record 12 of Set 11 | nador
# Processing Record 13 of Set 11 | erdemli
# Processing Record 14 of Set 11 | djambala
# Processing Record 15 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | koratla
# Processing Record 18 of Set 11 | deulgaon raja
# Processing Record 19 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 11 | central point
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 11 | kuopio
# Processing Record 23 of Set 11 | shirokiy
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 26 of Set 11 | sabha
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | high level
# Processing Record 29 of Set 11 | cocotitlan
# Processing Record 30 of Set 11 | irricana
# Processing Record 31 of Set 11 | warmbad
# Processing Record 32 of Set 11 | petatlan
# Processing Record 33 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 11 | shaki
# Processing Record 35 of Set 11 | tocopilla
# Processing Record 36 of Set 11 | ayan
# Processing Record 37 of Set 11 | byron bay
# Processing Record 38 of Set 11 | sale
# Processing Record 39 of Set 11 | itaobim
# Processing Record 40 of Set 11 | makakilo city
# Processing Record 41 of Set 11 | shingu
# Processing Record 42 of Set 11 | kismayo
# Processing Record 43 of Set 11 | linchuan
# City not found. Skipping...
# Processing Record 44 of Set 11 | nouakchott
# Processing Record 45 of Set 11 | mae sot
# Processing Record 46 of Set 11 | shenandoah
# Processing Record 47 of Set 11 | sakakah
# Processing Record 48 of Set 11 | ismailia
# Processing Record 49 of Set 11 | usinsk
# Processing Record 50 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 1 of Set 12 | urk
# Processing Record 2 of Set 12 | bolshaya izhora
# Processing Record 3 of Set 12 | tongliao
# Processing Record 4 of Set 12 | maumere
# Processing Record 5 of Set 12 | kedrovyy
# Processing Record 6 of Set 12 | rudnogorsk
# Processing Record 7 of Set 12 | yarmouth
# Processing Record 8 of Set 12 | cascais
# Processing Record 9 of Set 12 | zelenoborskiy
# Processing Record 10 of Set 12 | half moon bay
# Processing Record 11 of Set 12 | ushtobe
# Processing Record 12 of Set 12 | raton
# Processing Record 13 of Set 12 | fairbanks
# Processing Record 14 of Set 12 | gambela
# Processing Record 15 of Set 12 | chivay
# Processing Record 16 of Set 12 | tura
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | igarka
# Processing Record 19 of Set 12 | fort nelson
# Processing Record 20 of Set 12 | san francisco
# Processing Record 21 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 22 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 23 of Set 12 | huetamo
# City not found. Skipping...
# Processing Record 24 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 12 | adolfo lopez mateos
# Processing Record 27 of Set 12 | salinopolis
# Processing Record 28 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 29 of Set 12 | northport
# Processing Record 30 of Set 12 | athens
# Processing Record 31 of Set 12 | juneau
# Processing Record 32 of Set 12 | noumea
# Processing Record 33 of Set 12 | raichur
# Processing Record 34 of Set 12 | aksu
# Processing Record 35 of Set 12 | luoyang
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | tshane
# Processing Record 38 of Set 12 | chapais
# Processing Record 39 of Set 12 | bafq
# Processing Record 40 of Set 12 | suraabad
# Processing Record 41 of Set 12 | eureka
# Processing Record 42 of Set 12 | airai
# Processing Record 43 of Set 12 | anloga
# Processing Record 44 of Set 12 | greenville
# Processing Record 45 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 12 | flagstaff
# Processing Record 47 of Set 12 | inhambane
# Processing Record 48 of Set 12 | camacha
# Processing Record 49 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 12 | gat
# Processing Record 1 of Set 13 | olinda
# Processing Record 2 of Set 13 | andenes
# Processing Record 3 of Set 13 | erzin
# Processing Record 4 of Set 13 | honningsvag
# Processing Record 5 of Set 13 | athni
# Processing Record 6 of Set 13 | mollendo
# Processing Record 7 of Set 13 | murray bridge
# Processing Record 8 of Set 13 | general roca
# Processing Record 9 of Set 13 | victor harbor
# Processing Record 10 of Set 13 | tanabe
# Processing Record 11 of Set 13 | winnemucca
# Processing Record 12 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 13 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 13 | los llanos de aridane
# Processing Record 15 of Set 13 | port macquarie
# Processing Record 16 of Set 13 | mlonggo
# Processing Record 17 of Set 13 | mabaruma
# Processing Record 18 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 19 of Set 13 | imphal
# Processing Record 20 of Set 13 | weston
# Processing Record 21 of Set 13 | darya khan mari
# City not found. Skipping...
# Processing Record 22 of Set 13 | gaziantep
# Processing Record 23 of Set 13 | oxilithos
# Processing Record 24 of Set 13 | marquette
# Processing Record 25 of Set 13 | longonjo
# Processing Record 26 of Set 13 | papara
# Processing Record 27 of Set 13 | liuzhou
# Processing Record 28 of Set 13 | paranhos
# Processing Record 29 of Set 13 | baley
# Processing Record 30 of Set 13 | yuanping
# Processing Record 31 of Set 13 | maxixe
# Processing Record 32 of Set 13 | baykit
# Processing Record 33 of Set 13 | durusu
# Processing Record 34 of Set 13 | honiara
# Processing Record 35 of Set 13 | susanville
# Processing Record 36 of Set 13 | padang
# Processing Record 37 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 38 of Set 13 | tooele
# Processing Record 39 of Set 13 | gubkinskiy
# Processing Record 40 of Set 13 | bintulu
# Processing Record 41 of Set 13 | nchelenge
# Processing Record 42 of Set 13 | egvekinot
# Processing Record 43 of Set 13 | melfi
# Processing Record 44 of Set 13 | miracema do tocantins
# Processing Record 45 of Set 13 | alexandria
# Processing Record 46 of Set 13 | bassar
# Processing Record 47 of Set 13 | burnie
# Processing Record 48 of Set 13 | reconquista
# Processing Record 49 of Set 13 | fort-shevchenko
# Processing Record 50 of Set 13 | santa helena
# Processing Record 1 of Set 14 | zhanakorgan
# Processing Record 2 of Set 14 | buraydah
# Processing Record 3 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 4 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 5 of Set 14 | gondanglegi
# Processing Record 6 of Set 14 | valdepenas
# Processing Record 7 of Set 14 | marystown
# Processing Record 8 of Set 14 | chake chake
# Processing Record 9 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 14 | ankazoabo
# Processing Record 11 of Set 14 | buala
# Processing Record 12 of Set 14 | semme
# Processing Record 13 of Set 14 | san lawrenz
# Processing Record 14 of Set 14 | brigham city
# Processing Record 15 of Set 14 | impfondo
# Processing Record 16 of Set 14 | mana
# Processing Record 17 of Set 14 | feijo
# Processing Record 18 of Set 14 | plaeng yao
# Processing Record 19 of Set 14 | dalen
# Processing Record 20 of Set 14 | banatski karlovac
# Processing Record 21 of Set 14 | neiafu
# Processing Record 22 of Set 14 | gizo
# Processing Record 23 of Set 14 | mchinji
# Processing Record 24 of Set 14 | smiltene
# Processing Record 25 of Set 14 | flin flon
# Processing Record 26 of Set 14 | iberia
# Processing Record 27 of Set 14 | mizan teferi
# Processing Record 28 of Set 14 | ponnani
# Processing Record 29 of Set 14 | maragogi
# Processing Record 30 of Set 14 | addis zemen
# City not found. Skipping...
# Processing Record 31 of Set 14 | zapolyarnyy
# Processing Record 32 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 14 | gunnedah
# Processing Record 34 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 14 | kaabong
# Processing Record 36 of Set 14 | haradok
# Processing Record 37 of Set 14 | charters towers
# Processing Record 38 of Set 14 | lavrentiya
# Processing Record 39 of Set 14 | moa
# Processing Record 40 of Set 14 | quirinopolis
# Processing Record 41 of Set 14 | abrau-dyurso
# Processing Record 42 of Set 14 | camocim
# Processing Record 43 of Set 14 | vestmannaeyjar
# Processing Record 44 of Set 14 | pacific grove
# Processing Record 45 of Set 14 | ahipara
# Processing Record 46 of Set 14 | malakal
# Processing Record 47 of Set 14 | nikolsk
# Processing Record 48 of Set 14 | aleksandrov gay
# Processing Record 49 of Set 14 | mumford
# Processing Record 50 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 15 | morristown
# Processing Record 2 of Set 15 | la rioja
# Processing Record 3 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 15 | taldan
# Processing Record 5 of Set 15 | tevaitoa
# Processing Record 6 of Set 15 | magaria
# Processing Record 7 of Set 15 | raga
# Processing Record 8 of Set 15 | hobbs
# Processing Record 9 of Set 15 | huaihua
# Processing Record 10 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 15 | san carlos
# Processing Record 12 of Set 15 | kamaishi
# Processing Record 13 of Set 15 | manavalakurichi
# Processing Record 14 of Set 15 | tete
# Processing Record 15 of Set 15 | koumac
# Processing Record 16 of Set 15 | cabedelo
# Processing Record 17 of Set 15 | svetlogorsk
# Processing Record 18 of Set 15 | nishihara
# Processing Record 19 of Set 15 | mahibadhoo
# Processing Record 20 of Set 15 | magistralnyy
# Processing Record 21 of Set 15 | mae hong son
# Processing Record 22 of Set 15 | makushino
# Processing Record 23 of Set 15 | dunedin
# Processing Record 24 of Set 15 | omboue
# Processing Record 25 of Set 15 | khorinsk
# Processing Record 26 of Set 15 | kaa-khem
# Processing Record 27 of Set 15 | severnyy
# Processing Record 28 of Set 15 | berbera
# Processing Record 29 of Set 15 | katima mulilo
# Processing Record 30 of Set 15 | muika
# City not found. Skipping...
# Processing Record 31 of Set 15 | hovd
# Processing Record 32 of Set 15 | teguise
# Processing Record 33 of Set 15 | bonavista
# Processing Record 34 of Set 15 | funadhoo
# Processing Record 35 of Set 15 | aktash
# Processing Record 36 of Set 15 | dakar
# Processing Record 37 of Set 15 | caravelas
# Processing Record 38 of Set 15 | mangan
# Processing Record 39 of Set 15 | comodoro rivadavia
# Processing Record 40 of Set 15 | virginia beach
# Processing Record 41 of Set 15 | umm lajj
# Processing Record 42 of Set 15 | livenka
# Processing Record 43 of Set 15 | silver city
# Processing Record 44 of Set 15 | alegrete
# Processing Record 45 of Set 15 | imeni poliny osipenko
# Processing Record 46 of Set 15 | kavaratti
# Processing Record 47 of Set 15 | baruun-urt
# Processing Record 48 of Set 15 | palafrugell
# Processing Record 49 of Set 15 | wakkanai
# Processing Record 50 of Set 15 | bonfim
# Processing Record 1 of Set 16 | riyadh
# Processing Record 2 of Set 16 | kudat
# Processing Record 3 of Set 16 | sheregesh
# Processing Record 4 of Set 16 | port hedland
# Processing Record 5 of Set 16 | nouadhibou
# Processing Record 6 of Set 16 | riviere-au-renard
# Processing Record 7 of Set 16 | rosetta
# Processing Record 8 of Set 16 | katherine
# Processing Record 9 of Set 16 | guatire
# Processing Record 10 of Set 16 | farrukhabad
# Processing Record 11 of Set 16 | beidao
# Processing Record 12 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 16 | huarmey
# Processing Record 14 of Set 16 | sao joaquim
# ------------------------
# Data Retrieval Complete
# ------------------------

# %%
#len(city_data)
# Convert arrays to DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Shelburne  44.0787  -80.2041     68.23        47          72
# 1          Coihaique -45.5752  -72.0662     43.41        87          75
# 2       Punta Arenas -53.1500  -70.9167     46.51        87           0
# 3         Codrington -38.2667  141.9667     44.55        81          94
# 4               Hofn  64.2539  -15.2082     51.82        93         100
# 5             Dingle  10.9995  122.6711     77.85        87         100
# 6  San Mateo Del Mar  16.2000  -95.0000     80.67        76         100
# 7         Nelson Bay -32.7167  152.1500     45.00        94           0
# 8           Cherskiy  68.7500  161.3000     56.86        38          34
# 9        Tuktoyaktuk  69.4541 -133.0374     33.80        93         100
#
#    Wind Speed Country              Description                 Date
# 0        2.93      CA            broken clouds  2022-06-13 16:29:56
# 1        3.44      CL            broken clouds  2022-06-13 16:29:56
# 2       10.36      CL                clear sky  2022-06-13 16:29:57
# 3        8.75      AU          overcast clouds  2022-06-13 16:29:57
# 4        6.91      IS  light intensity drizzle  2022-06-13 16:29:57
# 5        3.96      PH     heavy intensity rain  2022-06-13 16:29:57
# 6        4.59      MX          overcast clouds  2022-06-13 16:29:58
# 7        5.28      AU                clear sky  2022-06-13 16:29:58
# 8        2.48      RU         scattered clouds  2022-06-13 16:29:58
# 9        9.22      CA                     mist  2022-06-13 16:26:04

# %%
# Create output file
output_data_file = "WeatherPy_Database.csv"
# Export
city_data_df.to_csv(output_data_file, index_label="City_ID")
